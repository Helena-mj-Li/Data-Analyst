# %% [markdown]
# Please create a heatmap which combines day of week and hour of day to see
#
# the distribution of the number of orders, to be more specific:
#
# based on orders dataframe,
#
# 1. create a new dataframe with first column name as order_dow, and the rest of columns name as the content of order_hour_of_day, dataframe value as count of orders.
#
# See examples in attached image.
#
# 2. Use seaborn heatmap function to create a heatmap visualization based on the dataframe above.

# %% [markdown]
#                 order_dow as index, order_hour_of_day as column,
# count of orders as value

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
sns.set(style="darkgrid")

# %%
orders = pd.read_csv("orders.csv")

# %%
orders.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2398795        1             2          3                  7
# 2    473747        1             3          3                 12
# 3   2254736        1             4          4                  7
# 4    431534        1             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
oh = orders.groupby('order_hour_of_day').count()

# %%
oh
# Out:
#                    order_id  user_id  order_number  order_dow  \
# order_hour_of_day
# 0                     22758    22758         22758      22758
# 1                     12398    12398         12398      12398
# 2                      7539     7539          7539       7539
# 3                      5474     5474          5474       5474
# 4                      5527     5527          5527       5527
# 5                      9569     9569          9569       9569
# 6                     30529    30529         30529      30529
# 7                     91868    91868         91868      91868
# 8                    178201   178201        178201     178201
# 9                    257812   257812        257812     257812
# 10                   288418   288418        288418     288418
# 11                   284728   284728        284728     284728
# 12                   272841   272841        272841     272841
# 13                   277999   277999        277999     277999
# ...

# %%
df = orders.groupby(['order_dow','order_hour_of_day'])['order_id'].size()

# %%
new = pd.DataFrame(df)

# %%
new
# Out:
#                              order_id
# order_dow order_hour_of_day
# 0         0                      3936
#           1                      2398
#           2                      1409
#           3                       963
#           4                       813
# ...                               ...
# 6         19                    18346
#           20                    13392
#           21                    10501
#           22                     8532
#           23                     6087
#
# [168 rows x 1 columns]

# %%
import pandas as pd
 
values = list(new['order_id'])
 
code = list(new['order_dow'])
 
df = pd.DataFrame(values, index=code, columns=list(new['order_hour_of_day']))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-168-4d99ab4523e9> in <module>()
#       1 import pandas as pd
#       2
# ----> 3 values = list(new['order_id'])
#       4
#       5 code = list(new['order_dow'])
#
# TypeError: 'Series' object is not callable

# %%
new['order_id'].tolist()
# Out:
# [3936,
#  2398,
#  1409,
#  963,
#  813,
#  1168,
#  3329,
#  12410,
#  28108,
#  40798,
#  48465,
#  51035,
#  51443,
#  53849,
#  54552,
#  53954,
#  49463,
#  39753,
#  29572,
#  22654,
#  18277,
#  14423,
#  11246,
#  6887,
#  3674,
#  1830,
#  1105,
#  748,
#  809,
#  1607,
#  5370,
#  16571,
#  34116,
#  51908,
#  55671,
#  51584,
#  47079,
#  46728,
#  46764,
#  46403,
#  44761,
#  36792,
#  28977,
#  22145,
#  16281,
#  11943,
#  8992,
#  5620,
#  3059,
#  1572,
#  943,
#  719,
#  744,
#  1399,
#  4758,
#  13245,
#  24635,
#  36314,
#  39230,
#  38128,
#  35780,
#  36650,
#  37173,
#  37469,
#  37541,
#  32151,
#  26470,
#  20084,
#  15039,
#  10653,
#  8146,
#  5358,
#  2952,
#  1495,
#  953,
#  654,
#  719,
#  1355,
#  4562,
#  12396,
#  22553,
#  32312,
#  36040,
#  35215,
#  33455,
#  34161,
#  34773,
#  35990,
#  35273,
#  30368,
#  25001,
#  19249,
#  13795,
#  10278,
#  8242,
#  5181,
#  2642,
#  1512,
#  899,
#  686,
#  730,
#  1330,
#  4401,
#  12493,
#  21814,
# ...

# %%
type(new['order_id'].tolist())
# Out:
# list

# %%
sns.distplot(x, kde=False, rug=True)
sns.distplot(x, bins=20, kde=False, rug=True)
