# %% [markdown]
# ### Add reordered column in order_product table
#
# For one customer, if a product is ordered for the first time, mark it as 0, otherwise mark it as 1.
#
# Please do it in both Python and SQL. For your sql query, create a table called order_product_new which contains the reordered column.

# %%
import pandas as pd
import numpy as np

# %%
order_products = pd.read_csv("order_products.csv")
orders = pd.read_csv("orders.csv")
ordernew = order_products.merge(orders, how="left", on="order_id")
ordernew
# Out:
#          order_id  product_id  add_to_cart_order  user_id  order_number  \
# 0               2       33120                  1   202279             3
# 1               2       28985                  2   202279             3
# 2               2        9327                  3   202279             3
# 3               2       45918                  4   202279             3
# 4               2       30035                  5   202279             3
# ...           ...         ...                ...      ...           ...
# 1048570    110719       26209                  1    43660            28
# 1048571    110719       35140                  2    43660            28
# 1048572    110720       28849                  1   119133             7
# 1048573    110720       35594                  2   119133             7
# 1048574    110720       16185                  3   119133             7
#
#          order_dow  order_hour_of_day  days_since_prior_order
# ...

# %%
grouped = ordernew.groupby(by=['user_id','product_id'])

# %%
ordernew['rank'] = grouped['order_number'].rank(ascending=True)

# %%
ordernew
# Out:
#          order_id  product_id  add_to_cart_order  user_id  order_number  \
# 0               2       33120                  1   202279             3
# 1               2       28985                  2   202279             3
# 2               2        9327                  3   202279             3
# 3               2       45918                  4   202279             3
# 4               2       30035                  5   202279             3
# ...           ...         ...                ...      ...           ...
# 1048570    110719       26209                  1    43660            28
# 1048571    110719       35140                  2    43660            28
# 1048572    110720       28849                  1   119133             7
# 1048573    110720       35594                  2   119133             7
# 1048574    110720       16185                  3   119133             7
#
#          order_dow  order_hour_of_day  days_since_prior_order  rank
# ...

# %%
ordernew['reordered'] = 0
ordernew.loc[ordernew['rank'] != 1] = 1
ordernew
# Out:
#          order_id  product_id  add_to_cart_order  user_id  order_number  \
# 0               2       33120                  1   202279             3
# 1               2       28985                  2   202279             3
# 2               2        9327                  3   202279             3
# 3               2       45918                  4   202279             3
# 4               2       30035                  5   202279             3
# ...           ...         ...                ...      ...           ...
# 1048570    110719       26209                  1    43660            28
# 1048571    110719       35140                  2    43660            28
# 1048572    110720       28849                  1   119133             7
# 1048573    110720       35594                  2   119133             7
# 1048574    110720       16185                  3   119133             7
#
#          order_dow  order_hour_of_day  days_since_prior_order  rank  reordered
# ...

# %%
zero = ordernew[ordernew["reordered"] == 0]
one = ordernew[ordernew["reordered"] == 1]
print("number of reordered==0: ", zero.shape[0])
print("number of reordered==1: ", one.shape[0])
# Out:
# number of reordered==0:  954567
# number of reordered==1:  94008

# %%
ordernew
# Out:
#          order_id  product_id  add_to_cart_order  user_id  order_number  \
# 0               2       33120                  1   202279             3
# 1               2       28985                  2   202279             3
# 2               2        9327                  3   202279             3
# 3               2       45918                  4   202279             3
# 4               2       30035                  5   202279             3
# ...           ...         ...                ...      ...           ...
# 1048570    110719       26209                  1    43660            28
# 1048571    110719       35140                  2    43660            28
# 1048572    110720       28849                  1   119133             7
# 1048573    110720       35594                  2   119133             7
# 1048574    110720       16185                  3   119133             7
#
#          order_dow  order_hour_of_day  days_since_prior_order  rank  reordered
# ...

# %%
ordernew_csv = ordernew.to_csv('ordernew.csv', index=False)

# %%
pd.read_csv('ordernew.csv')
# Out:
#          order_id  product_id  add_to_cart_order  user_id  order_number  \
# 0               2       33120                  1   202279             3
# 1               2       28985                  2   202279             3
# 2               2        9327                  3   202279             3
# 3               2       45918                  4   202279             3
# 4               2       30035                  5   202279             3
# ...           ...         ...                ...      ...           ...
# 1048570    110719       26209                  1    43660            28
# 1048571    110719       35140                  2    43660            28
# 1048572    110720       28849                  1   119133             7
# 1048573    110720       35594                  2   119133             7
# 1048574    110720       16185                  3   119133             7
#
#          order_dow  order_hour_of_day  days_since_prior_order  rank  reordered
# ...

# %%
ordernew['rank'] = ordernew.groupby(['user_id','product_id'])['order_number'].rank()

# %%
ordernew
# Out:
#          order_id  product_id  add_to_cart_order  user_id  order_number  \
# 0               2       33120                  1   202279             3
# 1               2       28985                  2   202279             3
# 2               2        9327                  3   202279             3
# 3               2       45918                  4   202279             3
# 4               2       30035                  5   202279             3
# ...           ...         ...                ...      ...           ...
# 1048570    110719       26209                  1    43660            28
# 1048571    110719       35140                  2    43660            28
# 1048572    110720       28849                  1   119133             7
# 1048573    110720       35594                  2   119133             7
# 1048574    110720       16185                  3   119133             7
#
#          order_dow  order_hour_of_day  days_since_prior_order  rank  reordered
# ...

# %%
ordernew['reordered']=ordernew.order_number.apply(lambda x: 0 if ordernew['rank']==1 else 1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-131-8cb965e66404> in <module>()
# ----> 1 ordernew['reordered']=ordernew.order_number.apply(lambda x: 0 if ordernew['rank']==1 else 1)
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4198             else:
#    4199                 values = self.astype(object)._values
# -> 4200                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4201
#    4202         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-131-8cb965e66404> in <lambda>(x)
# ----> 1 ordernew['reordered']=ordernew.order_number.apply(lambda x: 0 if ordernew['rank']==1 else 1)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1328     def __nonzero__(self):
# ...

# %%
ordernew['reordered']=ordernew.order_number.apply(lambda x: 0 if int(ordernew['rank'])==1 else 1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-132-0ce7c0f98f7b> in <module>()
# ----> 1 ordernew['reordered']=ordernew.order_number.apply(lambda x: 0 if int(ordernew['rank'])==1 else 1)
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4198             else:
#    4199                 values = self.astype(object)._values
# -> 4200                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4201
#    4202         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-132-0ce7c0f98f7b> in <lambda>(x)
# ----> 1 ordernew['reordered']=ordernew.order_number.apply(lambda x: 0 if int(ordernew['rank'])==1 else 1)
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in wrapper(self)
#     127         if len(self) == 1:
# ...
