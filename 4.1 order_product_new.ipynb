# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
order_products = pd.read_csv("order_products.csv")

# %%
order_products
# Out:
#           order_id  product_id  add_to_cart_order
# 0                2       33120                  1
# 1                2       28985                  2
# 2                2        9327                  3
# 3                2       45918                  4
# 4                2       30035                  5
# ...            ...         ...                ...
# 33819101   3421063       14233                  3
# 33819102   3421063       35548                  4
# 33819103   3421070       35951                  1
# 33819104   3421070       16953                  2
# 33819105   3421070        4724                  3
#
# [33819106 rows x 3 columns]

# %%
orders = pd.read_csv("orders.csv")

# %%
orders
# Out:
#          order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0         2539329        1             1          2                  8
# 1         2398795        1             2          3                  7
# 2          473747        1             3          3                 12
# 3         2254736        1             4          4                  7
# 4          431534        1             5          4                 15
# ...           ...      ...           ...        ...                ...
# 3421078   2266710   206209            10          5                 18
# 3421079   1854736   206209            11          4                 10
# 3421080    626363   206209            12          1                 12
# 3421081   2977660   206209            13          1                 12
# 3421082    272231   206209            14          6                 14
#
#          days_since_prior_order
# 0                           NaN
# 1                          15.0
# ...

# %%
ordernew = pd.merge(order_products, orders, on = "order_id")

# %%
ordernew
# Out:
#           order_id  product_id  add_to_cart_order  user_id  order_number  \
# 0                2       33120                  1   202279             3
# 1                2       28985                  2   202279             3
# 2                2        9327                  3   202279             3
# 3                2       45918                  4   202279             3
# 4                2       30035                  5   202279             3
# ...            ...         ...                ...      ...           ...
# 33819101   3421063       14233                  3   169679            30
# 33819102   3421063       35548                  4   169679            30
# 33819103   3421070       35951                  1   139822            15
# 33819104   3421070       16953                  2   139822            15
# 33819105   3421070        4724                  3   139822            15
#
#           order_dow  order_hour_of_day  days_since_prior_order
# ...

# %% [markdown]
# Add reordered column in order_product table
#
# For one customer, if a product is ordered for the first time, mark it as 0, otherwise mark it as 1.
#
# Please do it in both Python and SQL. For your sql query, create a table called order_product_new which contains the reordered column.

# %%
ordernew['reordered'] = 0

# %%
ordernew
# Out:
#           order_id  product_id  add_to_cart_order  user_id  order_number  \
# 0                2       33120                  1   202279             3
# 1                2       28985                  2   202279             3
# 2                2        9327                  3   202279             3
# 3                2       45918                  4   202279             3
# 4                2       30035                  5   202279             3
# ...            ...         ...                ...      ...           ...
# 33819101   3421063       14233                  3   169679            30
# 33819102   3421063       35548                  4   169679            30
# 33819103   3421070       35951                  1   139822            15
# 33819104   3421070       16953                  2   139822            15
# 33819105   3421070        4724                  3   139822            15
#
#           order_dow  order_hour_of_day  days_since_prior_order  reordered
# ...

# %%
# order_products['reordered'] = order_products.product_id.apply(lambda x: 1 if 'C' in x else 0)

# %%
ordernew['product_id'].groupby([ordernew.user_id]).value_counts()
# Out:
# user_id  product_id
# 1        196           11
#          10258         10
#          12427         10
#          25133          9
#          13032          4
#                        ..
# 206209   41665          1
#          42606          1
#          44325          1
#          48370          1
#          48697          1
# Name: product_id, Length: 13863746, dtype: int64

# %%
ordernew.groupby([ordernew.user_id])['product_id'].value_counts()
# Out:
# user_id  product_id
# 1        196           11
#          10258         10
#          12427         10
#          25133          9
#          13032          4
#                        ..
# 206209   41665          1
#          42606          1
#          44325          1
#          48370          1
#          48697          1
# Name: product_id, Length: 13863746, dtype: int64

# %% [markdown]
# 把每一个user_id 分类，查看是否有重复的product_id

# %%
df=pd.DataFrame(ordernew.groupby(['user_id'])['product_id'].value_counts())

# %%
df
# Out:
#                     product_id
# user_id product_id
# 1       196                 11
#         10258               10
#         12427               10
#         25133                9
#         13032                4
# ...                        ...
# 206209  41665                1
#         42606                1
#         44325                1
#         48370                1
#         48697                1
#
# [13863746 rows x 1 columns]

# %%
df.columns = ['count']

# %%
df
# Out:
#                     count
# user_id product_id
# 1       196            11
#         10258          10
#         12427          10
#         25133           9
#         13032           4
# ...                   ...
# 206209  41665           1
#         42606           1
#         44325           1
#         48370           1
#         48697           1
#
# [13863746 rows x 1 columns]

# %%
pd.DataFrame(df['count'] ==1)
# Out:
#                     count
# user_id product_id
# 1       196         False
#         10258       False
#         12427       False
#         25133       False
#         13032       False
# ...                   ...
# 206209  41665        True
#         42606        True
#         44325        True
#         48370        True
#         48697        True
#
# [13863746 rows x 1 columns]

# %%
ordernew['reordered'] = df['product_id'].apply(lambda x: 1 if df.count == False else 0)
# df['order_canceled'] = df['InvoiceNo'].apply(lambda x:int('C' in x))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in reindexer(value)
#    3726                 try:
# -> 3727                     value = value.reindex(self.index)._values
#    3728                 except ValueError as err:
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in reindex(self, index, **kwargs)
#    4398     def reindex(self, index=None, **kwargs):
# -> 4399         return super().reindex(index=index, **kwargs)
#    4400
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in reindex(self, *args, **kwargs)
#    4461         return self._reindex_axes(
# -> 4462             axes, level, limit, tolerance, method, fill_value, copy
#    4463         ).__finalize__(self, method="reindex")
#
# ...
